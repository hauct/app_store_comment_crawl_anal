# %%
import google.generativeai as genai

# %%
genai.configure(api_key='AIzaSyAEGOVl_Tv5sKKvzN-NhbWoYZnNPqFeP8U')

# %%
generation_config = {
  "candidate_count": 1,
  "max_output_tokens": 256,
  "temperature": 1.0,
  "top_p": 0.7,
}

safety_settings=[
  {
    "category": "HARM_CATEGORY_DANGEROUS",
    "threshold": "BLOCK_NONE",
  },
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_NONE",
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_NONE",
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_NONE",
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_NONE",
  },
]

model = genai.GenerativeModel(
    model_name="gemini-pro",
    generation_config=generation_config,
    safety_settings=safety_settings
)

# %%
def classify_emotion(text):
    response = model.generate_content(f'Bạn là một nhà phân loại cảm xúc xuất sắc hãy phân loại content sau thuộc loại gì? Chỉ cần trả lời là pos hoặc neg hoặc neu: {text}')
    return response.text

# %%
def summary_review(text):
    response = model.generate_content(f'Bạn là một nhà tóm tắt ý chính của comment xuất sắc\
        , Hãy phân loại thành một trong các loại sau: Bào Tiền\
        /Văng ra khỏi game/Chê gameplay/Không vào được game/\
        /Không tải được game/Khen gameplay, đồ họa đẹp, cốt truyện cuốn/Lag, giật, chậm/Bug game/\
        Lỗi tài khoản/Nóng, cấu hình cao\
        Góp ý cho game/Other.\
        Chỉ được dùng một trong các phân loại trên, không cần ghi thêm hoặc ghi khác: {text}')
    return response.text

# %%
app_reviews_df['emotion'] = app_reviews_df['reviews'].apply(lambda x: classify_emotion(x))
app_reviews_df['summary_review'] = app_reviews_df['reviews'].apply(lambda x: summary_review(x))

# %%
app_reviews_df.to_excel('app_reviews_df.xlsx', index=False, encoding='utf-8')
# Out:
# c:\Users\cungt\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
import pandas as pd
import sqldf

# %%
app_reviews_df = pd.read_excel('app_reviews_df.xlsx')
app_reviews_df.head()
# Out:
#                                              reviews  ratings        date  \
# 0  Càng ngày nhàm chán, event k có tiền thì cút k...        1  2024-02-26
# 1  Đang chơi thì văng ra, vô lại thì bảo là vi ph...        1  2024-01-02
# 2  NPH vô trách nhiệm , thay đổi điều chỉnh game ...        1  2024-02-26
# 3  Càng ngày nhàm chán, event k có tiền thì cút k...        1  2024-02-26
# 4  Đang chơi thì văng ra, vô lại thì bảo là vi ph...        1  2024-01-02
#
#   summary_review
# 0       Bào Tiền
# 1      Văng game
# 2   Chê gameplay
# 3       Bào Tiền
# 4      Văng game

# %%
app_reviews_df[app_reviews_df['summary_review'].isnull()].head()
# Out:
#                                               reviews  ratings        date  \
# 78                        Sao vào lại tự quay lại nhỉ        2  2023-08-18
# 79                               Game hay nhưng lag v        4  2023-10-07
# 80                                    Ko lên đc lv 60        1  2023-08-09
# 81                              R s nay k cập nhật dc        4  2023-08-22
# 82  Quá Hay Mà Còn Đánh Nhau Trên Trời Nếu Như Mà ...        5  2023-09-15
#
#    summary_review
# 78           None
# 79           None
# 80           None
# 81           None
# 82           None

# %%
date_now = '2024-01-02'
    # WHERE date = '{date_now}'

summary_review_agg_query = f'''
    SELECT date, summary_review, COUNT(summary_review) AS summary_review_num
    FROM app_reviews_df
    GROUP BY date, summary_review
    ORDER BY date DESC, summary_review 
'''

summary_review_agg = sqldf.run(summary_review_agg_query)

# %%
summary_review_agg.head(30)
# Out:
#           date       summary_review  summary_review_num
# 0   2024-02-27                 None                   0
# 1   2024-02-26                 None                   0
# 2   2024-02-26             Bào Tiền                   2
# 3   2024-02-26         Chê gameplay                   2
# 4   2024-02-25                 None                   0
# 5   2024-02-25        Khen gameplay                   1
# 6   2024-02-24                 None                   0
# 7   2024-02-24        Khen gameplay                   1
# 8   2024-02-16                 None                   0
# 9   2024-02-06        Khen gameplay                   1
# 10  2024-02-04                 None                   0
# 11  2024-02-01  Không tải được game                   1
# 12  2024-01-31             Bào Tiền                   1
# 13  2024-01-30                 None                   0
# 14  2024-01-28         Chê gameplay                   1
# 15  2024-01-27                 None                   0
# ...

# %%
## Tham số của database
PASSWORDS = "rJl<|QNC3o3I6GzZz].,T7A?"
HOST = "10.50.44.215"
PORT = "5432"
DB_NAME = "gs2_internal"
USER = "postgres"
